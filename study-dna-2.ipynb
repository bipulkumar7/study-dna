# %% [markdown]
# ## Objective:
#
# - Question 1.Create a master file for columns A, B and C (chromosome, position and ID) and this master should include unique combinations of A, B, C from ALL samples in that folder
# - Question 2.Identify the count of RSID (column C with RSIDxxxx) and blanks (“.” In column C) for each sample.
# - Question 3.Provide the number of rows with an RSID (column C and typically starts with RSxxxxxx) for each Chromosome (column A that starts with Chr1, 2.. etc.)
# - Question 4.For each unique RSID (columns C from the master data that is created in step a.), give the count of the number of samples that have that unique RSID. We should be able to execute this file
#
#
#
#
#
# * The above solution was unable to apply on the sample MODY_SMAPLES_VCF_FILES.zip
#     *https://drive.google.com/file/d/132xQnwHmLnAWYXwu1PbiRpvoP9ynUUQx/view*
#
#
#
#
#
# - Question 1 : It is showed empty in the link you have shared. Can you run all the files which are in this link. And check unique combinations.
# - Question 2: Can you give RSID count based on each file and combined count also.
# - Question 4: Can you give solution in a table so that it will be easy for understanding result.
#
#
# - Reason: The given data MODY_SMAPLES_VCF_FILES.zip was messy.
#           Required 1-485 lines to remove from each file.
#           Also added a column name FILE_N with the file name in master table.
#
#
#
# ![DNA-Model.jpg](attachment:DNA-Model.jpg)

# %% [markdown]
# |No.|File name| No. Columns|No. Rows| Size in MB |
# |---:|:-------------|:-----------|:-----------|:-------|
# |1|SAM12652700.haplotypecaller.hardfiltered.vcf|10|652472|128.2 MB|
# |2|SAM12652701.haplotypecaller.hardfiltered.vcf|10 |3789| 678.3 kB|
# |3|SAM12652702.haplotypecaller.hardfiltered.vcf|10 |198134| 40.1 MB|
# |4|SAM12652704.haplotypecaller.hardfiltered.vcf|10 |279131| 56.1 MB|
# |5|SAM12652705.haplotypecaller.hardfiltered.vcf|10 |350595| 69.4 MB|
# |6|SAM12652707.haplotypecaller.hardfiltered.vcf|10 | 74758| 15.1 MB|
# |7|SAM12652709.haplotypecaller.hardfiltered.vcf|10 |324872| 65.0 MB|
# |8|SAM12652710.haplotypecaller.hardfiltered.vcf|10 |307211| 61.8 MB|
# |9|SAM12652711.haplotypecaller.hardfiltered.vcf|10 |215261| 43.5 MB|
# |10|SAM12652712.haplotypecaller.hardfiltered.vcf|10 |349066| 69.4 MB|
# |11|SAM12652713.haplotypecaller.hardfiltered.vcf|10 |295946| 58.7 MB|
# |12|SAM12652716.haplotypecaller.hardfiltered.vcf|10 |334670| 65.3 MB|
# |13|SAM12652717.haplotypecaller.hardfiltered.vcf|10 |295090| 58.6 MB|
# |14|SAM12652719.haplotypecaller.hardfiltered.vcf|10 |258927| 52.0 MB|
# |15|SAM12652720.haplotypecaller.hardfiltered.vcf|10 |328280| 65.2 MB|
# |16|SAM12652721.haplotypecaller.hardfiltered.vcf|10 |303394| 60.2 MB|
# |17|SAM17751395.haplotypecaller.hardfiltered.vcf|10 |257164| 51.9 MB|
# |18|SAM17751397.haplotypecaller.hardfiltered.vcf|10 |251083| 50.7 MB|
# |19|SAM17751403.haplotypecaller.hardfiltered.vcf|10 |300866| 60.5 MB|
# |20|SAM17751404.haplotypecaller.hardfiltered.vcf|10 |273196| 55.5 MB|
# |21|SAM17751405.haplotypecaller.hardfiltered.vcf|10 |294967| 59.1 MB|
# |22|SAM17751406.haplotypecaller.hardfiltered.vcf|10 |383317| 75.6 MB |
# |23|SAM17751408.haplotypecaller.hardfiltered.vcf|10 |293099| 59.1 MB|
# |24|SAM17751409.haplotypecaller.hardfiltered.vcf|10 |246587| 50.3 MB|
# |25|SAM17751410.haplotypecaller.hardfiltered.vcf|10 |300120| 59.0 MB|
# |26|SAM17751411.haplotypecaller.hardfiltered.vcf|10 |390217| 75.8 MB|
# |27|SAM17751412.haplotypecaller.hardfiltered.vcf|10 |329294| 64.4 MB|
# |28|SAM17751413.haplotypecaller.hardfiltered.vcf|10 |168804| 35.0 MB|
# |29|SAM17751414.haplotypecaller.hardfiltered.vcf|10 |246080| 50.0 MB|
# |30|SAM17856303.haplotypecaller.hardfiltered.vcf|10 |907458| 175.5 MB|
# |31|SAM19532336.haplotypecaller.hardfiltered.vcf|10 |294070| 58.3 MB|
# |32|SAM20106726.haplotypecaller.hardfiltered.vcf|10 | 37623| 7.5 MB|
# |33|SAM20106728.haplotypecaller.hardfiltered.vcf|10 | 34846| 6.8 MB|
# |34|SAM20106729.haplotypecaller.hardfiltered.vcf|10 | 31781| 6.6 MB|
# |35|SAM20106732.haplotypecaller.hardfiltered.vcf|10 | 30492| 6.1 MB|
# |36|SAM20106734.haplotypecaller.hardfiltered.vcf|10 | 50964| 9.6 MB|
# |37|SAM20106737.haplotypecaller.hardfiltered.vcf|10 | 36556| 7.1 MB|
# |38|SAM20106743.haplotypecaller.hardfiltered.vcf|10 | 27778| 5.6 MB|
# |39|SAM20106747.haplotypecaller.hardfiltered.vcf|10 | 24586| 5.0 MB|
# |40|SAM20106751.haplotypecaller.hardfiltered.vcf|10 | 22604| 4.7 MB|
# |41|SAM20106752.haplotypecaller.hardfiltered.vcf|10 | 54687| 10.2 MB|
# |42|SAM20106762.haplotypecaller.hardfiltered.vcf|10 | 25469| 5.2 MB|
# |43|SAM20106765.haplotypecaller.hardfiltered.vcf|10 | 58841| 10.7 MB|
# |44|SAM20106782.haplotypecaller.hardfiltered.vcf|10 | 37831| 7.4 MB|
# |45|SAM20560633.haplotypecaller.hardfiltered.vcf|10 | 65598| 12 MB|
# |46|SAM20560643.haplotypecaller.hardfiltered.vcf|10 | 25942| 5.3 MB|
# | |   TOTAL ROWS                                |   |10073470|  1.9G  |

# %% [markdown]
# ## Let's solve

# %% [markdown]
# - DATA CLEANSING

# %% [markdown]
# - Iterating each file in a directory
# ```
# - Copying a file
# rsync -rv ../../MODY_SAMPLES_VCF_FILES/MODY_SMAPLES_VCF_FILES__original/ .
#
# - Deleting a first 485 lines from each files in a directory.
# ```
#     for FILE in *; do sed -i 1,485d $FILE; done
#     for FILE in *; do echo $FILE{1:5}; done  #NAMING THE FILE.
# ```
# - Adding columns with file name
#
# ```
#  for FILE in *; do awk 'NR==1 { G=$10; print $0"\tFILE_N"; } NR > 1 { print $0"\t"G }' $FILE > ${FILE::11}.TXT ; done
#  ```

# %% [markdown]
# ## Creating database `sam` with table `SAM_tbl`

# %%
from __future__ import print_function

import mysql.connector
from mysql.connector import errorcode

DB_NAME = 'samD'

TABLES = {}
TABLES['SAM_tbl'] = (
    "CREATE TABLE `SAM_tbl` ("
    "  `CHROM` VARCHAR(24),"
    "  `POS` INTEGER,"
    "  `ID` VARCHAR(120),"
    "  `REF` VARCHAR(205),"
    "  `ALT` VARCHAR(160),"
    "  `QUAL` FLOAT,"
    "  `FILTER` VARCHAR(7),"
    "  `INFO` VARCHAR(190),"
    "  `FORMAT` VARCHAR(14),"
    "  `SAM12652700` VARCHAR(58),"
    "  `FILE_N` VARCHAR(11)"
    ") ENGINE=InnoDB")


cnx = mysql.connector.connect(user='root',host='xxx', password='xxx', auth_plugin='mysql_native_password')
cursor = cnx.cursor()


def create_database(cursor):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(DB_NAME))
        cursor.execute("SET GLOBAL local_infile=1")
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)

try:
    cursor.execute("USE {}".format(DB_NAME))
    cursor.execute("SET GLOBAL local_infile=1")
except mysql.connector.Error as err:
    print("Database {} does not exists.".format(DB_NAME))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor)
        print("Database {} created successfully.".format(DB_NAME))
        cnx.database = DB_NAME
    else:
        print(err)
        exit(1)

        
for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")


cursor.close()
cnx.close()
# Out:
# Database samD does not exists.
# Database samD created successfully.
# Creating table SAM_tbl: OK

# %%
import mysql.connector as sql
import pandas as pd
import matplotlib.pyplot as plt
import glob

# Connecting database.
db_connection = sql.connect(host='xxx', database='sam', user='xxx', password='xxx', auth_plugin='mysql_native_password')
db_cursor = db_connection.cursor()
# assign directory
directory = '/home/ubuntu/'
 
Counts = {}

def TotalCounts_Table(sql):
    '''
    Couting total number of rows in a table.
    '''
    db_cursor.execute(sql)
    table_rows = db_cursor.fetchall()
    
    return table_rows

    
def LoadData(sql):
    '''
     iterate over files in that directory and 
     Load the data into mysql database
    '''
    for filename in glob.iglob(f'{directory}/SAM*'):
        sql=f"LOAD DATA LOCAL INFILE '{filename}' INTO TABLE SAM_tbl IGNORE 1 ROWS;"
        db_cursor.execute(sql)
        
    db_connection.commit()
    table_rows = db_cursor.fetchone()
    if table_rows is None:
        
        sql=f"SELECT COUNT(1) FROM SAM_tbl"
        print("Total number of rows in SAM_tbl: ", TotalCounts_Table(sql)[0][0])
        
    return table_rows 


# Load the file data into table SAM_tbl
df = pd.DataFrame(LoadData(sql))
print(df)
# Out:
# Total number of rows in SAM_tbl:  10073470
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Answers for  MODY_SMAPLES_VCF_FILES.zip
#
# ![DNA-Original.png](attachment:DNA-Original.png)
#
# ### 1.
# - Create a master file for columns A, B and C (chromosome, position and ID) and this master should include unique combinations of A, B, C from ALL samples in that folder

# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='xxx', database='sam', user='xxx', password='xxx', auth_plugin='mysql_native_password')
db_cursor = db_connection.cursor()

def Create_MasterTable(sql,sql2):
    """
    Create a master file for columns A, B and C (chromosome, position and ID) 
    and this master should include unique combinations of A, B, C from ALL samples in that folder
    
    SELECT DISTINCT CHROM , POS, ID FROM SAM_tbl;
    SELECT CHROM, POS, ID FROM SAM_tbl GROUP BY CHROM, POS, ID;

    CREATE TABLE master ( CHROM VARCHAR(23), POS INTEGER, ID VARCHAR(117), PRIMARY KEY (CHROM, POS, ID));  INSERT INTO master SELECT DISTINCT CHROM, POS, ID FROM SAM_tbl;
    CREATE TABLE master ( CHROM VARCHAR(23), POS INTEGER, ID VARCHAR(117) );  INSERT INTO master SELECT DISTINCT CHROM, POS, ID FROM SAM_tbl;

    CREATE TABLE master AS SELECT DISTINCT CHROM, POS, ID FROM SAM_tbl;
    """
    db_cursor.execute(sql)
    table_rows = db_cursor.fetchone()
    
    if table_rows is None:
        db_cursor.execute(sql2)
        table_rows = db_cursor.fetchall()
        return table_rows
    
    return table_rows



sql = "CREATE TABLE master AS SELECT DISTINCT CHROM , POS, ID FROM SAM_tbl;"
sql2 = "SELECT COUNT(1) FROM master;"
table_rows = Create_MasterTable(sql, sql2)
print("Total number of rows found in master: ", table_rows[0][0])

#End of the connection
db_cursor.close()
db_connection.close()
# Out:
# Total number of rows found in master:  3795092

# %% [markdown]
# ### 2
#
# - Identify the count of RSID (column C with RSIDxxxx) and blanks (“.” In column C) for each sample.
#  ```
#  SELECT COUNT(DISTINCT(ID)) as TOTAL_NOS FROM SAM_tbl WHERE FILE_N= 'SAMXXXX' AND ID like 'rs%';
#  SELECT COUNT(DISTINCT(ID)) as TOTAL_NOS FROM MASTER_DATA WHERE ID like 'rs%';
#  ```

# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='xxx', database='sam', user='xxx', password='xxx', auth_plugin='mysql_native_password')
db_cursor = db_connection.cursor()
RSID_counts = {}
Empty_RSID_counts = {}


def IdentifyRSID_count():
    '''
    Identify the count of RSID (column C with RSIDxxxx) 
    SELECT COUNT(DISTINCT(ID)) as TOTAL_NOS FROM SAM_tbl WHERE FILE_N= 'SAMXXXX' AND ID like 'rs%';
    '''
    for filename in glob.iglob(f'{directory}/SAM*'):
        file=filename[13:24]
        sql = f"SELECT COUNT(DISTINCT(ID)) as TOTAL_NOS FROM SAM_tbl WHERE FILE_N= '{file}' AND ID like 'rs%'"
        db_cursor.execute(sql)
        table_rows = db_cursor.fetchall()
        RSID_counts[file] = table_rows[0][0]
  


def IdentifyEmpty_count():
    '''
    Identify the count of RSID (column C with RSIDxxxx) and blanks (“.” In column C) for each sample. 
    SELECT COUNT(DISTINCT(ID)) as TOTAL_NOS FROM MASTER_DATA WHERE ID like 'rs%';
    '''
    for filename in glob.iglob(f'{directory}/SAM*'):
        file=filename[13:24]
        sql = f"SELECT COUNT(ID) as TOTAL_NOS FROM SAM_tbl WHERE FILE_N= '{file}' AND ID not like 'rs%'"
        db_cursor.execute(sql)
        table_rows = db_cursor.fetchall()
        Empty_RSID_counts[file] = table_rows[0][0]
    
    
    #End of the connection
    db_cursor.close()
    db_connection.close()
    
IdentifyRSID_count()
IdentifyEmpty_count()
    

for file, counts in RSID_counts.items():
    print(f"File name {file} having RSID's {counts} and Empty", Empty_RSID_counts[file])
# Out:
# File name SAM17751408 having RSID's 264150 and Empty 28948
# File name SAM12652709 having RSID's 294538 and Empty 30333
# File name SAM20106752 having RSID's 39771 and Empty 14915
# File name SAM17751409 having RSID's 222116 and Empty 24470
# File name SAM12652711 having RSID's 192888 and Empty 22372
# File name SAM20106737 having RSID's 29358 and Empty 7197
# File name SAM17751395 having RSID's 224091 and Empty 33072
# File name SAM17751412 having RSID's 298527 and Empty 30766
# File name SAM17751406 having RSID's 347488 and Empty 35828
# File name SAM20106732 having RSID's 25446 and Empty 5045
# File name SAM17751403 having RSID's 275612 and Empty 25253
# File name SAM12652707 having RSID's 68319 and Empty 6438
# File name SAM19532336 having RSID's 276272 and Empty 17797
# File name SAM17751411 having RSID's 327680 and Empty 62536
# File name SAM12652700 having RSID's 589311 and Empty 63160
# File name SAM17751404 having RSID's 248842 and Empty 24353
# ...

# %% [markdown]
# ### 3
# - Provide the number of rows with an RSID (column C and typically starts with RSxxxxxx) for each Chromosome (column A that starts with Chr1, 2.. etc.)

# %%
import mysql.connector as sql
import pandas as pd
import matplotlib.pyplot as plt


db_connection = sql.connect(host='xxx', database='sam', user='root', password='xxx', auth_plugin='mysql_native_password')
db_cursor = db_connection.cursor()

def Num_RowsEachChromosome(sql):
    """
    Provide the number of rows with an RSID (column C and typically starts with RSxxxxxx) 
    for each Chromosome (column A that starts with Chr1, 2.. etc.) Make pareto chart

    SELECT COUNT(DISTINCT(ID)) as NO_RSID,CHROM FROM  SAM_tbl GROUP BY CHROM; #NOT APPLIED
    SELECT COUNT(ID) as NO_RSID,CHROM FROM  SAM_tbl GROUP BY CHROM;

    SELECT COUNT(DISTINCT(ID)) as NO_RSID, CHROM FROM  SAM_tbl WHERE ID LIKE 'rs%' GROUP BY CHROM;
    """
    db_cursor.execute(sql)
    table_rows = db_cursor.fetchall()
    #End of the connection
    db_cursor.close()
    db_connection.close()
    
    return table_rows


sql = "SELECT COUNT(DISTINCT(ID)) as NO_RSID, CHROM FROM  SAM_tbl WHERE ID LIKE 'rs%' GROUP BY CHROM;"
df = pd.DataFrame(Num_RowsEachChromosome(sql))
#display(df)

def MakeParetoChart(CHROM, RSID_COUNT):
 
    # Figure Size
    fig, ax = plt.subplots(figsize =(16,16))
 
    # Horizontal Bar Plot
    ax.barh(CHROM, RSID_COUNT)
 
    # Show top values
    ax.invert_yaxis()
 
    # Add annotation to bars
    for i in ax.patches:
        plt.text(i.get_width()+0.3, i.get_y()+0.5,
                 str(round((i.get_width()), 2)),
                 fontsize = 10, fontweight ='bold',
                 color ='black')
      
    # Add Plot Title
    ax.set_title('Chromosom with number of RSID',
                 loc ='center', )

    # Add Text watermark
    fig.text(0.5, 0.13, 'Bipul Kumar', fontsize = 12,
             color ='grey', ha ='right', va ='bottom',
             alpha = 0.7)

    # Show Plot
    plt.show()
    
    
#Ploting on pareto chart
CHROM = df[1]
RSID_COUNT = df[0]
MakeParetoChart(CHROM, RSID_COUNT)

# %% [markdown]
# ### 4
# - For each unique RSID (columns C from the master data that is created in step a.), give the count of the number of samples that have that unique RSID. We should be able to execute this file

# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='xxx', database='sam', user='xxx', password='xxx', auth_plugin='mysql_native_password')
db_cursor = db_connection.cursor()

def Count_uniqueRSID(sql):
    """
    For each unique RSID (columns C from the master data that is created in step a.),
    give the count of the number of samples that have that unique RSID. We should be able to execute this file

    SELECT COUNT(DISTINCT(ID)) AS TOTAL_UNIQ_RSID FROM master WHERE ID LIKE 'rs%';
    """
    db_cursor.execute(sql)
    table_rows = db_cursor.fetchall()
    
    #End of the connection
    db_cursor.close()
    db_connection.close()
    
    return table_rows
 
    
    
sql = "SELECT COUNT(DISTINCT(ID)) AS TOTAL_UNIQ_RSID FROM master WHERE ID LIKE 'rs%'"


table_rows = Count_uniqueRSID(sql)
print("Total Unique RSID found in master table: ", table_rows[0][0])
# Out:
# Total Unique RSID found in master table:  2877559
